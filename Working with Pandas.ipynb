# %% [markdown]
# <a href="https://colab.research.google.com/github/edwardLum/star-struck/blob/main/Working%20with%20Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Inititalization
#
# ### Imports

# %%
import os

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### File Upload

# %%
from google.colab import files
uploaded = files.upload()

filenames = []

# Upload files:
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  filenames.append(fn)
# Out:
#      <input type="file" id="files-c3bdb253-9a0f-4951-812f-109e0670834e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3bdb253-9a0f-4951-812f-109e0670834e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Load data frame

# %%
search_terms = pd.read_csv("/content/" + filenames[0], skiprows=2)

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# **Inspection**

# %%
search_terms.head()
# Out:
#                     Search term   Match type Added/Excluded  \
# 0          hollywoodbets mobile  Broad match           None
# 1                 my bet betway  Broad match           None
# 2               bonus on betway  Broad match           None
# 3          sign up for free bet  Broad match           None
# 4  how to register for superbet  Broad match           None
#
#                Campaign  Ad group             Keyword Clicks Impr.  \
# 0  ZA | Search | Sports  Football  live bets Football      0     2
# 1  ZA | Search | Sports    Soccer          bet Soccer      0     1
# 2  ZA | Search | Sports    Soccer          bet Soccer      0     1
# 3  ZA | Search | Sports    Soccer          bet Soccer      0     1
# 4  ZA | Search | Sports    Soccer     live bet Soccer      0     1
#
#   Currency code  Avg. CPC  Cost Conversions  Cost / conv. Conv. rate    CTR
# 0           ZAR       0.0   0.0           0           0.0      0.00%  0.00%
# ...

# %%
search_terms.tail()
# Out:
#                               Search term                    Match type  \
# 64781  best betting sites in south africa  Phrase match (close variant)
# 64782                 Total: Search terms                           NaN
# 64783           Total: Other search terms                           NaN
# 64784                      Total: Account                           NaN
# 64785                       Total: Search                           NaN
#
#       Added/Excluded                              Campaign      Ad group  \
# 64781           None  ZA | Search | Generic sports betting  Test Ad Grou
# 64782            NaN                                   NaN           NaN
# 64783            NaN                                   NaN           NaN
# 64784            NaN                                   NaN           NaN
# 64785            NaN                                   NaN           NaN
#
#                 Keyword  Clicks      Impr. Currency code  Avg. CPC       Cost  \
# ...

# %%
search_terms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64786 entries, 0 to 64785
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Search term     64786 non-null  object
#  1   Match type      64782 non-null  object
#  2   Added/Excluded  64782 non-null  object
#  3   Campaign        64782 non-null  object
#  4   Ad group        64782 non-null  object
#  5   Keyword         64782 non-null  object
#  6   Clicks          64786 non-null  object
#  7   Impr.           64786 non-null  object
#  8   Currency code   64786 non-null  object
#  9   Avg. CPC        64786 non-null  float64
#  10  Cost            64786 non-null  float64
#  11  Conversions     64786 non-null  object
#  12  Cost / conv.    64786 non-null  float64
#  13  Conv. rate      64786 non-null  object
#  14  CTR             64786 non-null  object
# dtypes: float64(3), object(12)
# memory usage: 7.4+ MB

# %% [markdown]
# **Dealing with comma as thousand separator**

# %%
columns_with_comma = ["Clicks", "Impr.", "Conversions"]

for column in columns_with_comma:
  search_terms[column] = search_terms[column].str.replace(',', '').astype(float)

# %% [markdown]
# **Dealing with percentages**

# %%
search_terms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64786 entries, 0 to 64785
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Search term     64786 non-null  object
#  1   Match type      64782 non-null  object
#  2   Added/Excluded  64782 non-null  object
#  3   Campaign        64782 non-null  object
#  4   Ad group        64782 non-null  object
#  5   Keyword         64782 non-null  object
#  6   Clicks          64786 non-null  float64
#  7   Impr.           64786 non-null  float64
#  8   Currency code   64786 non-null  object
#  9   Avg. CPC        64786 non-null  float64
#  10  Cost            64786 non-null  float64
#  11  Conversions     64786 non-null  float64
#  12  Cost / conv.    64786 non-null  float64
#  13  Conv. rate      64786 non-null  object
#  14  CTR             64786 non-null  object
# dtypes: float64(6), object(9)
# memory usage: 7.4+ MB

# %% [markdown]
# ### Plotting quality score distribution

# %%
plt.figure(figsize=(12, 8))
quality_score_distribution.sort_values(ascending=False).plot(kind='bar')
plt.title('Percentage of Total Cost by Quality Score')
plt.xlabel('Quality Score')
plt.ylabel('Percentage of Total Cost')
plt.show()

# %%
#
